# %%
# modules, labraries import
import tensorflow as tf
import pandas as pd
import numpy as np
import rdkit.Chem as Chem
import rdkit.Chem.AllChem as AllChem

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Flatten, \
    Activation, BatchNormalization, LSTM, Dropout
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.preprocessing import MinMaxScaler

# %%
# make dataset
df = pd.read_csv('cmpd.csv')

# add to mol columns
df['mol'] = df.smiles.apply(Chem.MolFromSmiles)
df['mol'] = df.mol.apply(Chem.AddHs)

# add to number of atoms, number of heavy atoms columns
# separte inchikey based "-"
for idx in range(len(df)):
    temp_list = []
    temp_list.append(df.iloc[idx, 0].split("-"))
    df['num_of_atoms'] = df['mol'][idx].GetNumAtoms()
    df['num_of_heavy_atoms'] = df['mol'][idx].GetNumHeavyAtoms()
    df['inchikey_1'] = temp_list[0][0]
    df['inchikey_2'] = temp_list[0][1]

# sorted df columns
df = df[['inchikey', 'inchikey_1', 'inchikey_2', 'smiles', 'group', 'mol', 'num_of_atoms', 'num_of_heavy_atoms', 'activity']]
df
# Out:
#                          inchikey      inchikey_1  inchikey_2  \
# 0     FNHKPVJBJVTLMP-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 1     CUDVHEFYRIWYQD-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 2     TTZSNFLLYPYKIL-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 3     UOVCGJXDGOGOCZ-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 4     CUIHSIWYWATEQL-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# ...                           ...             ...         ...
# 5525  UBAHPEHGSJRHGA-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 5526  RTTIKBHDHKOSNI-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 5527  HVUOSZANYULBJR-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 5528  SNFWCJIVWUVRNO-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 5529  MKSAGABLDNGEAP-DHIUTWEWSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
#
#                                                  smiles  group  \
# 0     CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)...  train
# 1     CNC(=O)c1cccc2cc(Oc3ccnc4cc(OCC5(N)CC5)c(OC)cc...  train
# 2     Cc1cc2cc(Oc3ccnc(Nc4cccc(CS(=O)(=O)NCCN(C)C)c4...   test
# 3          COc1cc2c(cc1F)C(c1ccccc1Cl)=Nc1c(n[nH]c1C)N2  train
# 4     Cc1ccc(Nc2nccc(N(C)c3ccc4c(C)n(C)nc4c3)n2)cc1S...   test
# ...                                                 ...    ...
# 5525  Cc1cccc2nc(-c3ccc(-c4cccc(CN5CCC(C(N)=O)CC5)c4...   test
# 5526        Cc1c2ccccc2nc2c1c1cc(NCCN(C)C)ccc1n2CCN(C)C   test
# 5527  Cc1ccc(-c2ccn(-c3ccc4c5c(n(C)c4c3)CCCNC5)c(=O)...   test
# 5528  N#Cc1c(-c2ccccc2C(F)(F)F)nc(SCc2ccc(OC(F)(F)F)...   test
# 5529  CCOP(=O)(OCC)[C@@H]1C[C@H](C(=O)Nc2cc3c4c(cccc...   test
#
#                                                     mol  num_of_atoms  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x000001F946B...            74
# 1     <rdkit.Chem.rdchem.Mol object at 0x000001F952C...            74
# 2     <rdkit.Chem.rdchem.Mol object at 0x000001F952C...            74
# 3     <rdkit.Chem.rdchem.Mol object at 0x000001F952C...            74
# 4     <rdkit.Chem.rdchem.Mol object at 0x000001F952C...            74
# ...                                                 ...           ...
# 5525  <rdkit.Chem.rdchem.Mol object at 0x000001F952D...            74
# 5526  <rdkit.Chem.rdchem.Mol object at 0x000001F952D...            74
# 5527  <rdkit.Chem.rdchem.Mol object at 0x000001F952D...            74
# 5528  <rdkit.Chem.rdchem.Mol object at 0x000001F952D...            74
# 5529  <rdkit.Chem.rdchem.Mol object at 0x000001F952D...            74
#
#       num_of_heavy_atoms  activity
# 0                     39    active
# 1                     39    active
# 2                     39    active
# 3                     39    active
# 4                     39    active
# ...                  ...       ...
# 5525                  39  inactive
# 5526                  39  inactive
# 5527                  39  inactive
# 5528                  39  inactive
# 5529                  39  inactive
#
# [5530 rows x 9 columns]

# %%
# make train, test dataset formatted DataFrame
train = pd.DataFrame(columns=['inchikey', 'inchikey_1', 'inchikey_2', 'smiles', 'mol', 'num_of_atoms', 'num_of_heavy_atoms', 'activity'])
test = pd.DataFrame(columns=['inchikey', 'inchikey_1', 'inchikey_2', 'smiles', 'mol', 'num_of_atoms', 'num_of_heavy_atoms', 'activity'])

# add to values each columns
for idx in range(len(df)):
    if df.iloc[idx, 4] == 'train':
        train.loc[idx] = df.loc[idx, ['inchikey', 'inchikey_1', 'inchikey_2', 'smiles', 'mol', 'num_of_atoms', 'num_of_heavy_atoms', 'activity']]
    else:
        test.loc[idx] = df.loc[idx, ['inchikey', 'inchikey_1', 'inchikey_2', 'smiles', 'mol', 'num_of_atoms', 'num_of_heavy_atoms', 'activity']]

# reset index
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)
train
# Out:
#                          inchikey      inchikey_1  inchikey_2  \
# 0     FNHKPVJBJVTLMP-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 1     CUDVHEFYRIWYQD-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 2     UOVCGJXDGOGOCZ-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 3     IFPPYSWJNWHOLQ-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 4     WOSKHXYHFSIKNG-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# ...                           ...             ...         ...
# 3972  INSBKYCYLCEBOD-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 3973  KTUFNOKKBVMGRW-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 3974  SVRAGOOKTLUHES-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 3975  QQJUCFIPZAVTEU-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
# 3976  PDTYLGXVBIWRIM-UHFFFAOYSA-N  MKSAGABLDNGEAP  DHIUTWEWSA
#
#                                                  smiles  \
# 0     CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)...
# 1     CNC(=O)c1cccc2cc(Oc3ccnc4cc(OCC5(N)CC5)c(OC)cc...
# 2          COc1cc2c(cc1F)C(c1ccccc1Cl)=Nc1c(n[nH]c1C)N2
# 3     CCN(CC)CCOc1ccc(Nc2ncc3cc(-c4c(Cl)cccc4Cl)c(=O...
# 4     COc1cc2nccc(Oc3ccc(NC(=O)NC4CC4)c(Cl)c3)c2cc1C...
# ...                                                 ...
# 3972            O=C(O)Cc1c2ccccc2n2c1[nH]c(=O)c1ccccc12
# 3973  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...
# 3974       CN1CCC(n2cnc(-c3ccc(F)cc3)c2-c2ccnc(N)n2)CC1
# 3975  CC1(C)CC(n2cnc(-c3ccc(F)cc3)c2-c2ccnc(N)n2)CC(...
# 3976         COc1nccc(-c2c(-c3ccc(F)cc3)ncn2C2CCNCC2)n1
#
#                                                     mol num_of_atoms  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x000001F946B...           74
# 1     <rdkit.Chem.rdchem.Mol object at 0x000001F952C...           74
# 2     <rdkit.Chem.rdchem.Mol object at 0x000001F952C...           74
# 3     <rdkit.Chem.rdchem.Mol object at 0x000001F952C...           74
# 4     <rdkit.Chem.rdchem.Mol object at 0x000001F952C...           74
# ...                                                 ...          ...
# 3972  <rdkit.Chem.rdchem.Mol object at 0x000001F952D...           74
# 3973  <rdkit.Chem.rdchem.Mol object at 0x000001F952D...           74
# 3974  <rdkit.Chem.rdchem.Mol object at 0x000001F952D...           74
# 3975  <rdkit.Chem.rdchem.Mol object at 0x000001F952D...           74
# 3976  <rdkit.Chem.rdchem.Mol object at 0x000001F952D...           74
#
#      num_of_heavy_atoms  activity
# 0                    39    active
# 1                    39    active
# 2                    39    active
# 3                    39    active
# 4                    39    active
# ...                 ...       ...
# 3972                 39    active
# 3973                 39  inactive
# 3974                 39   unknown
# 3975                 39   unknown
# 3976                 39  inactive
#
# [3977 rows x 8 columns]

# %%
# split X, y (y is based on 'activity' column)
X_train = train.iloc[:, :-1]
y_train = train.iloc[:, -1].to_list()
X_test = test.iloc[:, :-1]
y_test = test.iloc[:, -1].to_list()

# %%
# make y string -> vector
def y_to_vec(list):
    for idx in range(len(list)):
        if list[idx] == 'active':
            list[idx] = 1
        else:
            list[idx] = 0
    return list

y_train = y_to_vec(y_train)
y_test = y_to_vec(y_test)

# one hot encoding y
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %%
# split train, validation dataset
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.9, random_state=23)

# %%
# tokenized X data
def make_dataset(df):
    temp_list = []

    for idx in range(len(df)):
        temp_list.append(df.iloc[idx, :])
    
    tokenizer = tf.keras.preprocessing.text.Tokenizer(lower=False, char_level=True)
    tokenizer.fit_on_texts(temp_list)
    top_k = len(tokenizer.word_index)

    temp_seq = tokenizer.texts_to_sequences(temp_list)
    temp_vec = tf.keras.preprocessing.sequence.pad_sequences(temp_seq, padding='post')
    return temp_vec

X_train = make_dataset(X_train)
X_val = make_dataset(X_val)
X_test = make_dataset(X_test)

# %%
# data scaling used MinMaxScaler
# scaler = MinMaxScaler()

# def mms(scaler, data):
#     mms = scaler
#     mms.fit(data)
#     data = mms.transform(data)
#     return data

# X_train = mms(scaler, X_train)
# X_val = mms(scaler, X_val)
# X_test = mms(scaler, X_test)

# %%
X_train
# Out:
# array([[   35,     1,     2, ...,    37,     3,     4],
#        [   38,     1,     2, ...,    40,     3,     4],
#        [   41,     1,     2, ...,    43,     3,     4],
#        ...,
#        [10696,     1,     2, ..., 10698,     3,     4],
#        [10699,     1,     2, ..., 10701,     3,     4],
#        [10702,     1,     2, ..., 10704,     3,     4]])

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)

print(len(np.unique(X_train)))
# Out:
# (3579, 7)
# (398, 7)
# (1553, 7)
# 10704

# %%
# modeling, used 'sigmoid' activation function in last layer
model = Sequential()
model.add(Embedding(input_dim=len(np.unique(X_train)), output_dim=10, input_length=7))
model.add(Flatten())
model.add(Dense(128))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(32))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(16))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(8))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(2))
model.add(Activation('sigmoid')) # binary classification (active(1), else(0))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 7, 10)             107040
#
#  flatten_4 (Flatten)         (None, 70)                0
#
#  dense_24 (Dense)            (None, 128)               9088
#
#  batch_normalization_20 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_24 (Activation)  (None, 128)               0
#
#  dense_25 (Dense)            (None, 64)                8256
#
#  batch_normalization_21 (Bat  (None, 64)               256
#  chNormalization)
#
#  activation_25 (Activation)  (None, 64)                0
#
#  dense_26 (Dense)            (None, 32)                2080
#
#  batch_normalization_22 (Bat  (None, 32)               128
#  chNormalization)
#
#  activation_26 (Activation)  (None, 32)                0
#
#  dense_27 (Dense)            (None, 16)                528
#
#  batch_normalization_23 (Bat  (None, 16)               64
#  chNormalization)
#
#  activation_27 (Activation)  (None, 16)                0
#
#  dense_28 (Dense)            (None, 8)                 136
#
#  batch_normalization_24 (Bat  (None, 8)                32
#  chNormalization)
#
#  activation_28 (Activation)  (None, 8)                 0
#
#  dense_29 (Dense)            (None, 2)                 18
#
#  activation_29 (Activation)  (None, 2)                 0
#
# =================================================================
# Total params: 128,138
# Trainable params: 127,642
# Non-trainable params: 496
# _________________________________________________________________

# %%
rl = ReduceLROnPlateau(mode='auto', monitor='val_loss', patience=10)

# %%
# complie, fitting and save model
model.compile(
    optimizer=Adam(),
    loss='binary_crossentropy',
    metrics='acc'
)

model.fit(
    X_train, y_train,
    validation_data=[X_val, y_val],
    epochs=100, batch_size=64
)

model.save(filepath='./model.h5')
# Out:
# Epoch 1/100
# 56/56 [==============================] - 3s 43ms/step - loss: 0.7391 - acc: 0.5007 - val_loss: 0.6938 - val_acc: 0.4749
# Epoch 2/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.5809 - acc: 0.7614 - val_loss: 0.6929 - val_acc: 0.5201
# Epoch 3/100
# 56/56 [==============================] - 2s 40ms/step - loss: 0.4555 - acc: 0.8997 - val_loss: 0.6905 - val_acc: 0.5553
# Epoch 4/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.3497 - acc: 0.9438 - val_loss: 0.6910 - val_acc: 0.5553
# Epoch 5/100
# 56/56 [==============================] - 2s 40ms/step - loss: 0.2562 - acc: 0.9743 - val_loss: 0.7036 - val_acc: 0.5578
# Epoch 6/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.1846 - acc: 0.9832 - val_loss: 0.7208 - val_acc: 0.5201
# Epoch 7/100
# 56/56 [==============================] - 2s 40ms/step - loss: 0.1300 - acc: 0.9908 - val_loss: 0.7862 - val_acc: 0.5176
# Epoch 8/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0947 - acc: 0.9944 - val_loss: 0.8600 - val_acc: 0.5327
# Epoch 9/100
# 56/56 [==============================] - 2s 39ms/step - loss: 0.0652 - acc: 0.9975 - val_loss: 0.9600 - val_acc: 0.5578
# Epoch 10/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0502 - acc: 0.9972 - val_loss: 1.1273 - val_acc: 0.5553
# Epoch 11/100
# 56/56 [==============================] - 2s 39ms/step - loss: 0.0368 - acc: 0.9989 - val_loss: 1.3338 - val_acc: 0.5427
# Epoch 12/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0271 - acc: 0.9994 - val_loss: 1.5676 - val_acc: 0.5452
# Epoch 13/100
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0215 - acc: 0.9997 - val_loss: 1.7335 - val_acc: 0.5276
# Epoch 14/100
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0179 - acc: 0.9992 - val_loss: 1.8463 - val_acc: 0.5503
# Epoch 15/100
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0166 - acc: 0.9994 - val_loss: 1.9580 - val_acc: 0.5427
# Epoch 16/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0157 - acc: 0.9989 - val_loss: 1.9930 - val_acc: 0.5402
# Epoch 17/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0143 - acc: 0.9992 - val_loss: 2.0636 - val_acc: 0.5402
# Epoch 18/100
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0158 - acc: 0.9983 - val_loss: 2.1086 - val_acc: 0.5503
# Epoch 19/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0136 - acc: 0.9978 - val_loss: 2.2118 - val_acc: 0.5377
# Epoch 20/100
# 56/56 [==============================] - 2s 39ms/step - loss: 0.0176 - acc: 0.9958 - val_loss: 2.2150 - val_acc: 0.5553
# Epoch 21/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0407 - acc: 0.9869 - val_loss: 2.4341 - val_acc: 0.5327
# Epoch 22/100
# 56/56 [==============================] - 2s 39ms/step - loss: 0.0648 - acc: 0.9793 - val_loss: 2.4961 - val_acc: 0.5327
# Epoch 23/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.1015 - acc: 0.9656 - val_loss: 2.6047 - val_acc: 0.5151
# Epoch 24/100
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0713 - acc: 0.9754 - val_loss: 2.5976 - val_acc: 0.5528
# Epoch 25/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.
100
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0125 - acc: 0.9969 - val_loss: 2.8689 - val_acc: 0.5452
# Epoch 81/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0067 - acc: 0.9992 - val_loss: 2.8147 - val_acc: 0.5427
# Epoch 82/100
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0036 - acc: 1.0000 - val_loss: 2.7869 - val_acc: 0.5477
# Epoch 83/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0029 - acc: 1.0000 - val_loss: 2.7887 - val_acc: 0.5503
# Epoch 84/100
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0021 - acc: 1.0000 - val_loss: 2.8206 - val_acc: 0.5503
# Epoch 85/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 2.8538 - val_acc: 0.5503
# Epoch 86/100
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 2.8878 - val_acc: 0.5503
# Epoch 87/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 2.9233 - val_acc: 0.5528
# Epoch 88/100
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 2.9567 - val_acc: 0.5528
# Epoch 89/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 2.9890 - val_acc: 0.5503
# Epoch 90/100
# 56/56 [==============================] - 3s 48ms/step - loss: 0.0010 - acc: 1.0000 - val_loss: 3.0252 - val_acc: 0.5528
# Epoch 91/100
# 56/56 [==============================] - 1s 9ms/step - loss: 9.3728e-04 - acc: 1.0000 - val_loss: 3.0547 - val_acc: 0.5528
# Epoch 92/100
# 56/56 [==============================] - 2s 41ms/step - loss: 8.3243e-04 - acc: 1.0000 - val_loss: 3.0816 - val_acc: 0.5553
# Epoch 93/100
# 56/56 [==============================] - 0s 9ms/step - loss: 7.6972e-04 - acc: 1.0000 - val_loss: 3.1095 - val_acc: 0.5553
# Epoch 94/100
# 56/56 [==============================] - 2s 40ms/step - loss: 7.1668e-04 - acc: 1.0000 - val_loss: 3.1361 - val_acc: 0.5553
# Epoch 95/100
# 56/56 [==============================] - 0s 8ms/step - loss: 7.5419e-04 - acc: 1.0000 - val_loss: 3.1606 - val_acc: 0.5553
# Epoch 96/100
# 56/56 [==============================] - 2s 39ms/step - loss: 5.9772e-04 - acc: 1.0000 - val_loss: 3.1845 - val_acc: 0.5578
# Epoch 97/100
# 56/56 [==============================] - 0s 8ms/step - loss: 7.5992e-04 - acc: 1.0000 - val_loss: 3.2168 - val_acc: 0.5578
# Epoch 98/100
# 56/56 [==============================] - 0s 8ms/step - loss: 5.8561e-04 - acc: 1.0000 - val_loss: 3.2421 - val_acc: 0.5553
# Epoch 99/100
# 56/56 [==============================] - 2s 9ms/step - loss: 5.7371e-04 - acc: 1.0000 - val_loss: 3.2603 - val_acc: 0.5553
# Epoch 100/100
# 56/56 [==============================] - 0s 8ms/step - loss: 5.1013e-04 - acc: 1.0000 - val_loss: 3.2857 - val_acc: 0.5528

# %%
# evaluate, predict test dataset
loss, _ = model.evaluate(
    X_test, y_test
)

y_pred = model.predict(X_test)[:, 1]
for idx in range(len(y_pred)):
    if y_pred[idx] > 0.5:
        y_pred[idx] = 1.
    else:
        y_pred[idx] = 0.

y_test_2 = []
for idx in range(len(y_test)):
    y_test_2.append(y_test[idx, 1])
# Out:
# 49/49 [==============================] - 0s 3ms/step - loss: 2.2157 - acc: 0.5100

# %%
# evaluate used sklearn metrics
acc_score = accuracy_score(y_test_2, y_pred)
recall = recall_score(y_test_2, y_pred)
precision = precision_score(y_test_2, y_pred)
f1 = f1_score(y_test_2, y_pred)

print("loss : ", loss)
print("acc_score : ", acc_score)
print("recall : ", recall)
print("precision : ", precision)
print("f1 : ", f1)
# Out:
# loss :  2.215696096420288
# acc_score :  0.5093367675466839
# recall :  0.5448028673835126
# precision :  0.37438423645320196
# f1 :  0.4437956204379562
